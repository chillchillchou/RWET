# %% [markdown]
# ## for loop
#     for ??? in list
#         print()
#         print()

# %%
cheese = ["cheddar","cambert"]

# %%
print("\n".join(cheese))
# Out:
# cheddar
# cambert

# %%
for i in range(10):
    print("😆😆")
# Out:
# 😆😆
# 😆😆
# 😆😆
# 😆😆
# 😆😆
# 😆😆
# 😆😆
# 😆😆
# 😆😆
# 😆😆

# %%
for i in range(5,10,2):
    print(i)
# Out:
# 5
# 7
# 9

# %% [markdown]
# ## write a computer-generated acrostic
#     send phrase (phrase to spell out)
#     source text (draw the lines of poetry)
#
#     ROBERT FROST

# %%
words = open("frost.txt").read().split()

# %% [markdown]
# ### database??
#     "r" ->["rober","road"
#     "o" ->["other","of"]
#     Then ask the database to give me all of the words that start with "r" "o" "b"...
#
#     Dictionary

# %%
plane_dis = {"Mercury":0.387, "Venus":0.723, "Earth":1.0, "Mars": 1.523}

# %%
plane_dis
# Out:
# {'Earth': 1.0, 'Mars': 1.523, 'Mercury': 0.387, 'Venus': 0.723}

# %%
type(plane_dis)
# Out:
# dict

# %%
plane_dis["Venus"]
# Out:
# 0.723

# %%
"Mars" in plane_dis
# Out:
# True

# %%
plane_dis['jupiter'] = 5.2

# %%
plane_dis
# Out:
# {'Earth': 1.0, 'Mars': 1.523, 'Mercury': 0.387, 'Venus': 0.723, 'jupiter': 5.2}

# %%
plane_dis["jupiter"]+=2

# %%
number_words = {0:"zero",1:"one",2:"two"}

# %%
planet_moons = {
    "Mercury":[],
    "Venus":[],
    "Earth":["Moon"],
    "Mars":["Phobos","Demino"],
}

# %%
len(planet_moons["Earth"])
# Out:
# 1

# %%
planet_moons["Earth"].append("Allison")

# %%
planet_moons
# Out:
# {'Earth': ['Moon', 'Allison'],
#  'Mars': ['Phobos', 'Demino'],
#  'Mercury': [],
#  'Venus': []}

# %% [markdown]
# ### what we want to end up with
#     {'a':["as","above"],
#      'b':["both","bent"],
#      'c':["could","could","claims".
#      }

# %%
initials={}
#look at the first letter of each word, check to see if there's already an entry in initials
#if the first letter is not alreay a key, add it with an empety list
#if it is then add the word to the list value

# %%
for item in words:
    first_let = item[0]
    if first_let not in initials:
        initials[first_let]=[]
    initials[first_let].append(item)
    print(item, first_let, initials)
    print()
# Out:
# Two T {'T': ['Two', 'To', 'Then', 'Though', 'Two', 'Two'], 'r': ['roads', 'really', 'roads'], 'd': ['diverged', 'down', 'day!', 'doubted', 'diverged', 'difference.'], 'i': ['in', 'it', 'in', 'it', 'if', 'in'], 'a': ['a', 'as', 'as', 'as', 'as', 'and', 'as', 'about', 'another', 'a', 'ages', 'and', 'ages', 'a', 'and', 'all'], 'y': ['yellow'], 'w': ['wood,', 'where', 'was', 'wanted', 'wear;', 'worn', 'way', 'way,', 'with', 'wood,'], 'A': ['And', 'And', 'And', 'And', 'And', 'And'], 's': ['sorry', 'stood', 'same,', 'step', 'should', 'shall', 'sigh'], 'I': ['I', 'I', 'I', 'In', 'I', 'I', 'I', 'I', 'I—', 'I'], 'c': ['could', 'could', 'claim,', 'come'], 'n': ['not', 'no'], 't': ['travel', 'traveler,', 'the', 'took', 'the', 'the', 'that', 'the', 'there', 'them', 'the', 'that', 'trodden', 'the', 'to', 'telling', 'this', 'took', 'the', 'travelled', 'that', 'the'], 'b': ['both', 'be', 'bent', 'better', 'both', 'black.', 'back.', 'be', 'by,'], 'o': ['one', 'one', 'other,', 'on', 'one'], 'l': ['lo
# ...

# %%
test=eval(open("area.txt").read())

# %%
type(test)
# Out:
# list

# %%
print(test)
# Out:
# [{'neighborhood': 'Central Bronx', 'zips': ['10453', '10457', '10460']}, {'neighborhood': 'Bronx Park and Fordham', 'zips': ['10458', '10467', '10468']}, {'neighborhood': 'High Bridge and Morrisania', 'zips': ['10451', '10452', '10456']}, {'neighborhood': 'Hunts Point and Mott Haven', 'zips': ['10454', '10455', '10459', '10474']}, {'neighborhood': 'Kingsbridge and Riverdale', 'zips': ['10463', '10471']}, {'neighborhood': 'Northeast Bronx', 'zips': ['10466', '10469', '10470', '10475']}, {'neighborhood': 'Southeast Bronx', 'zips': ['10461', '10462', '10464', '10465', '10472', '10473']}, {'neighborhood': 'Central Brooklyn', 'zips': ['11212', '11213', '11216', '11233', '11238']}, {'neighborhood': 'Southwest Brooklyn', 'zips': ['11209', '11214', '11228']}, {'neighborhood': 'Borough Park', 'zips': ['11204', '11218', '11219', '11230']}, {'neighborhood': 'Canarsie and Flatlands', 'zips': ['11234', '11236', '11239']}, {'neighborhood': 'Southern Brooklyn', 'zips': ['11223', '11224', '11229', '
# ...

# %%
test[0]
# Out:
# {'neighborhood': 'Central Bronx', 'zips': ['10453', '10457', '10460']}

# %%
test[0]["neighborhood"]
# Out:
# 'Central Bronx'

# %%
neighborhood=[]

# %%
for item in test:
    neighborhood.append (item['neighborhood'])

# %%
print(neighborhood)
# Out:
# ['Central Bronx', 'Bronx Park and Fordham', 'High Bridge and Morrisania', 'Hunts Point and Mott Haven', 'Kingsbridge and Riverdale', 'Northeast Bronx', 'Southeast Bronx', 'Central Brooklyn', 'Southwest Brooklyn', 'Borough Park', 'Canarsie and Flatlands', 'Southern Brooklyn', 'Northwest Brooklyn', 'Flatbush', 'East New York and New Lots', 'Greenpoint', 'Sunset Park', 'Bushwick and Williamsburg', 'Central Harlem', 'Chelsea and Clinton', 'East Harlem', 'Gramercy Park and Murray Hill', 'Greenwich Village and Soho', 'Lower Manhattan', 'Lower East Side', 'Upper East Side', 'Upper West Side', 'Inwood and Washington Heights', 'Northeast Queens', 'North Queens', 'Central Queens', 'Jamaica', 'Northwest Queens', 'West Central Queens', 'Rockaways', 'Southeast Queens', 'Southwest Queens', 'West Queens', 'Port Richmond', 'South Shore', 'Stapleton and St. George', 'Mid-Island']
